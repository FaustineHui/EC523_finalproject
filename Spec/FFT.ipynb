# %%
import numpy as np
from PIL import Image
from copy import deepcopy
import os

# %%
# train_dirs = ['progan_train', 'progan_val']
# train_categories = ['car', 'cat', 'horse', 'person', 'sofa']
# labels = ['0_real', '1_fake']

# for train_dir in train_dirs:
#     for train_category in train_categories:
#         for label in labels:
            # direc = 'C:/Users/fuzha/Downloads/' + train_dir + '/' + train_category + '/' + label
            # images = os.listdir(direc)

# for image in images:
img = Image.open(direc + '/' + image)
img = np.array(img)

im = deepcopy(img[16:240,16:240,:])
im = im.astype(np.float32)
im = im/255.0
for i in range(3):
    img = im[:,:,i]
    fft_img = np.fft.fft2(img)
    fft_img = np.log(np.abs(fft_img)+1e-3)
    fft_min = np.percentile(fft_img,5)
    fft_max = np.percentile(fft_img,95)
    fft_img = (fft_img - fft_min)/(fft_max - fft_min)
    fft_img = (fft_img-0.5)*2
    fft_img[fft_img<-1] = -1
    fft_img[fft_img>1] = 1
    im[:,:,i] = fft_img

im = np.transpose(im, (2,0,1))

img = Image.fromarray(np.uint8(im[0]))
img
                # img.save('C:/Users/fuzha/Downloads/FFT/' + train_dir + '/' + train_category + '/' + label + '/' + image)
# Out:
# C:\Users\fuzha\AppData\Local\Temp/ipykernel_37124/1168841246.py:24: RuntimeWarning: invalid value encountered in true_divide
#   fft_img = (fft_img - fft_min)/(fft_max - fft_min)

# %%
test_categories = ['airplane','bicycle','bird','boat','bottle','bus','car','cat','chair','cow','diningtable','dog','horse','motorbike','person','pottedplant','sheep','sofa','train','tvmonitor']
labels = ['0_real', '1_fake']

for test_category in test_categories:
    for label in labels:
        direc = 'C:/Users/fuzha/Downloads/CNN_synth_testset/progan/' + test_category + '/' + label
        images = os.listdir(direc)

        for image in images:
            img = Image.open(direc + '/' + image)
            img = np.array(img)

            im = deepcopy(img[16:240,16:240,:])
            im = im.astype(np.float32)
            im = im/255.0
            for i in range(3):
                img = im[:,:,i]
                fft_img = np.fft.fft2(img)
                fft_img = np.log(np.abs(fft_img)+1e-3)
                fft_min = np.percentile(fft_img,5)
                fft_max = np.percentile(fft_img,95)
                fft_img = (fft_img - fft_min)/(fft_max - fft_min)
                fft_img = (fft_img-0.5)*2
                fft_img[fft_img<-1] = -1
                fft_img[fft_img>1] = 1
                im[:,:,i] = fft_img

            im = np.transpose(im, (2,0,1))

            img = Image.fromarray(np.uint8(im[0]))
            img.save('C:/Users/fuzha/Downloads/FFT/CNN_synth_testset/progan/' + test_category + '/' + label + '/' + image)

# %%
# test_gans = ['deepfake','stargan','whichfaceisreal']
test_gans = ['san']
labels = ['0_real', '1_fake']

for test_gan in test_gans:
    for label in labels:
        direc = 'C:/Users/fuzha/Downloads/CNN_synth_testset/' + test_gan + '/' + label
        images = os.listdir(direc)

        for image in images:
            img = Image.open(direc + '/' + image)
            img = np.array(img)

            im = deepcopy(img[16:240,16:240,:])
            im = im.astype(np.float32)
            im = im/255.0
            for i in range(3):
                img = im[:,:,i]
                fft_img = np.fft.fft2(img)
                fft_img = np.log(np.abs(fft_img)+1e-3)
                fft_min = np.percentile(fft_img,5)
                fft_max = np.percentile(fft_img,95)
                fft_img = (fft_img - fft_min)/(fft_max - fft_min)
                fft_img = (fft_img-0.5)*2
                fft_img[fft_img<-1] = -1
                fft_img[fft_img>1] = 1
                im[:,:,i] = fft_img

            im = np.transpose(im, (2,0,1))

            img = Image.fromarray(np.uint8(im[0]))
            img.save('C:/Users/fuzha/Downloads/FFT/CNN_synth_testset/' + test_gan + '/' + label + '/' + image)

# %%
test_categories = ['apple','horse','orange','summer','winter','zebra']
labels = ['0_real', '1_fake']

for test_category in test_categories:
    for label in labels:
        direc = 'C:/Users/fuzha/Downloads/CNN_synth_testset/cyclegan/' + test_category + '/' + label
        images = os.listdir(direc)

        for image in images:
            img = Image.open(direc + '/' + image)
            img = np.array(img)

            im = deepcopy(img[16:240,16:240,:])
            im = im.astype(np.float32)
            im = im/255.0
            for i in range(3):
                img = im[:,:,i]
                fft_img = np.fft.fft2(img)
                fft_img = np.log(np.abs(fft_img)+1e-3)
                fft_min = np.percentile(fft_img,5)
                fft_max = np.percentile(fft_img,95)
                fft_img = (fft_img - fft_min)/(fft_max - fft_min)
                fft_img = (fft_img-0.5)*2
                fft_img[fft_img<-1] = -1
                fft_img[fft_img>1] = 1
                im[:,:,i] = fft_img

            im = np.transpose(im, (2,0,1))

            img = Image.fromarray(np.uint8(im[0]))
            img.save('C:/Users/fuzha/Downloads/FFT/CNN_synth_testset/cyclegan/' + test_category + '/' + label + '/' + image)

# %%
test_categories = ['bedroom', 'car','cat']
labels = ['0_real', '1_fake']

for test_category in test_categories:
    for label in labels:
        direc = 'C:/Users/fuzha/Downloads/CNN_synth_testset/stylegan/' + test_category + '/' + label
        images = os.listdir(direc)

        for image in images:
            img = Image.open(direc + '/' + image)
            img = np.array(img)

            im = deepcopy(img[16:240,16:240,:])
            im = im.astype(np.float32)
            im = im/255.0
            for i in range(3):
                img = im[:,:,i]
                fft_img = np.fft.fft2(img)
                fft_img = np.log(np.abs(fft_img)+1e-3)
                fft_min = np.percentile(fft_img,5)
                fft_max = np.percentile(fft_img,95)
                fft_img = (fft_img - fft_min)/(fft_max - fft_min)
                fft_img = (fft_img-0.5)*2
                fft_img[fft_img<-1] = -1
                fft_img[fft_img>1] = 1
                im[:,:,i] = fft_img

            im = np.transpose(im, (2,0,1))

            img = Image.fromarray(np.uint8(im[0]))
            img.save('C:/Users/fuzha/Downloads/FFT/CNN_synth_testset/stylegan/' + test_category + '/' + label + '/' + image)

# %%
test_categories = ['car','cat','church','horse']
labels = ['0_real', '1_fake']

for test_category in test_categories:
    for label in labels:
        direc = 'C:/Users/fuzha/Downloads/CNN_synth_testset/stylegan2/' + test_category + '/' + label
        images = os.listdir(direc)

        for image in images:
            img = Image.open(direc + '/' + image)
            img = np.array(img)

            im = deepcopy(img[16:240,16:240,:])
            im = im.astype(np.float32)
            im = im/255.0
            for i in range(3):
                img = im[:,:,i]
                fft_img = np.fft.fft2(img)
                fft_img = np.log(np.abs(fft_img)+1e-3)
                fft_min = np.percentile(fft_img,5)
                fft_max = np.percentile(fft_img,95)
                fft_img = (fft_img - fft_min)/(fft_max - fft_min)
                fft_img = (fft_img-0.5)*2
                fft_img[fft_img<-1] = -1
                fft_img[fft_img>1] = 1
                im[:,:,i] = fft_img

            im = np.transpose(im, (2,0,1))

            img = Image.fromarray(np.uint8(im[0]))
            img.save('C:/Users/fuzha/Downloads/FFT/CNN_synth_testset/stylegan2/' + test_category + '/' + label + '/' + image)
